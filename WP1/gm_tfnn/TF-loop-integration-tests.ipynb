# %%
import numpy as np

import tensorflow as tf
from tfwrapper import TFClassifier
import itertools

# %%
def load_mnist():
    """Loads MNIST and preprocesses to combine training and validation data."""
    train, test = tf.keras.datasets.mnist.load_data()
    train_data, train_labels = train
    test_data, test_labels = test

    train_data = np.array(train_data, dtype=np.float32) / 255
    test_data = np.array(test_data, dtype=np.float32) / 255

    train_data = train_data.reshape((train_data.shape[0], 28, 28, 1))
    test_data = test_data.reshape((test_data.shape[0], 28, 28, 1))

    train_labels = np.array(train_labels, dtype=np.int32)
    test_labels = np.array(test_labels, dtype=np.int32)

    assert train_data.min() == 0.
    assert train_data.max() == 1.
    assert test_data.min() == 0.
    assert test_data.max() == 1.

    return train_data, train_labels, test_data, test_labels

# %%
X, y, X_test, y_test = load_mnist()

# %%
hyperpars = {
    'conv': True,
    'conv_sizes': (64, 64),
    'conv_kernel_size': (3,3),
    'conv_activation': 'relu',
    'regularizer': None,
    'dropout_rate': 0.0,
    'dense_sizes': (128, 128),
    'dense_activation': 'relu',
    'output_activation': 'softmax',
    'optimizer': 'adam',
    'loss': 'categorical_crossentropy',
    'batch_size': 32,
    'epochs': 1
}

# %%
nn = TFClassifier(**hyperpars)

# %%
nn.fit(X, y)
# Out:
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1365 - accuracy: 0.9580

# %%
nn.predict(X_test)
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=int64)

# %%
nn.predict_proba(X_test)
# Out:
# array([[2.32158030e-07, 1.29263776e-06, 8.07395645e-06, ...,
#         9.99977946e-01, 3.57516639e-09, 1.06737862e-05],
#        [8.67134295e-05, 9.87795556e-06, 9.99890924e-01, ...,
#         5.60322233e-09, 8.04031606e-06, 3.69110609e-09],
#        [2.21195879e-08, 9.99994397e-01, 2.64588266e-07, ...,
#         3.92634956e-06, 6.10319830e-08, 1.98706232e-07],
#        ...,
#        [2.00284100e-09, 1.46855484e-06, 7.94249466e-09, ...,
#         5.34901915e-07, 1.30450792e-06, 5.66366543e-06],
#        [5.14572712e-05, 3.27615481e-07, 3.91478920e-07, ...,
#         5.94108087e-07, 1.30780665e-02, 1.51623317e-04],
#        [6.01055126e-06, 2.93136786e-08, 1.01446094e-05, ...,
#         4.74395057e-09, 2.44954317e-05, 1.67628883e-07]], dtype=float32)

# %%
# Here's some parameters we might want to search over
param_grid = {
    'conv': [True],
    'conv_sizes': [[64,], [64, 64]],
    'conv_kernel_size': [[3, 3], [5, 5]],
    'conv_activation': ['tanh', 'relu'],
    'dense_sizes': [[128,], [128, 128]],
    'dense_activation': ['relu'],
    'output_activation': ['softmax'],
    'dropout_rate': [0.0, 0.2],
    'regularizer': [None, 'l2'],
    'optimizer': ['adam'],
    'loss': ['categorical_crossentropy'],
    'batch_size': [32, 64],
    'epochs': [1]
}
# Create a list with all combinations of the values
all_combinations = itertools.product(*param_grid.values())

for combination in all_combinations:
    # Turn this particular combination into a dictionary
    comb_dict = {n: v for n, v in zip(param_grid.keys(), combination)}
    print(comb_dict) # just to see that it is correct
    
    # Create the NN with these hyper-params
    nn = TFClassifier(**comb_dict)    
    # Fit
    nn.fit(X, y)
# Out:
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1586 - accuracy: 0.9525
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1886 - accuracy: 0.9444
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1996 - accuracy: 0.9401
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.2165 - accuracy: 0.9342
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1721 - accuracy: 0.9473
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 3ms/step - loss: 0.1841 - accuracy: 0.9454
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2296 - accuracy: 0.9298
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.2436 - accuracy: 0.9266
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6157 - accuracy: 0.8954
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.6167 - accuracy: 0.8956
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.7234 - accuracy: 0.8849
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.7172 - accuracy: 0.8846
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.7919 - accuracy: 0.8929
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.8858 - accuracy: 0.8953
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.9539 - accuracy: 0.8691
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 1.0115 - accuracy: 0.8692
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1353 - accuracy: 0.9603
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1651 - accuracy: 0.9508
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1642 - accuracy: 0.9502
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1879 - accuracy: 0.9436
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1436 - accuracy: 0.9557
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1699 - accuracy: 0.9478
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1879 - accuracy: 0.9417
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.2218 - accuracy: 0.9320
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5650 - accuracy: 0.9027
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 3s 3ms/step - loss: 0.5936 - accuracy: 0.8999
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6918 - accuracy: 0.8887
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.6943 - accuracy: 0.8852
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.7545 - accuracy: 0.8965
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.8642 - accuracy: 0.8929
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.9182 - accuracy: 0.8702
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.9953 - accuracy: 0.8699
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1532 - accuracy: 0.9539
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1739 - accuracy: 0.9479
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1806 - accuracy: 0.9462
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1938 - accuracy: 0.9412
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1623 - accuracy: 0.9506
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1785 - accuracy: 0.9468
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2292 - accuracy: 0.9305
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.2472 - accuracy: 0.9237
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5772 - accuracy: 0.9136
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 3s 3ms/step - loss: 0.5730 - accuracy: 0.9141
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.6965 - accuracy: 0.9019
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.6693 - accuracy: 0.9053: 0s - loss: 0.6816 - ac
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.7411 - accuracy: 0.9097
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.8388 - accuracy: 0.9062
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.8960 - accuracy: 0.8897
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.9383 - accuracy: 0.8896
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1176 - accuracy: 0.9650
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1373 - accuracy: 0.9599
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1454 - accuracy: 0.9566
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1668 - accuracy: 0.9490
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1291 - accuracy: 0.9607
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1513 - accuracy: 0.9546
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1814 - accuracy: 0.9435
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1940 - accuracy: 0.9404
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5150 - accuracy: 0.9270
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5360 - accuracy: 0.9237
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5994 - accuracy: 0.9156
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.6188 - accuracy: 0.9104
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6990 - accuracy: 0.9239
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.8030 - accuracy: 0.9191
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.8227 - accuracy: 0.9050
# {'conv': True, 'conv_sizes': [64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.9115 - accuracy: 0.9029
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1228 - accuracy: 0.9625
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1538 - accuracy: 0.9541
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1511 - accuracy: 0.9535
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1811 - accuracy: 0.9438
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1277 - accuracy: 0.9597
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1537 - accuracy: 0.9531
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1837 - accuracy: 0.9438
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2134 - accuracy: 0.9336
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5480 - accuracy: 0.9339
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5966 - accuracy: 0.9305
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6217 - accuracy: 0.9242
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.6800 - accuracy: 0.9184
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.7304 - accuracy: 0.9254
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.8834 - accuracy: 0.9262
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.8115 - accuracy: 0.9079
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.9336 - accuracy: 0.9057
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1231 - accuracy: 0.9622
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1488 - accuracy: 0.9553
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1490 - accuracy: 0.9537
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1825 - accuracy: 0.9431
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1313 - accuracy: 0.9595
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1616 - accuracy: 0.9510
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1741 - accuracy: 0.9458
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2096 - accuracy: 0.9345
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5217 - accuracy: 0.9363
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.6152 - accuracy: 0.9265
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.6133 - accuracy: 0.9201
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.6794 - accuracy: 0.9162
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.7126 - accuracy: 0.9251
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.8377 - accuracy: 0.9195
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.8040 - accuracy: 0.9056
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [3, 3], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 6s 5ms/step - loss: 0.9407 - accuracy: 0.8996
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1253 - accuracy: 0.9617
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1373 - accuracy: 0.9586
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1572 - accuracy: 0.9524
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1703 - accuracy: 0.9470
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1355 - accuracy: 0.9588
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1527 - accuracy: 0.9534
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1976 - accuracy: 0.9390
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2105 - accuracy: 0.9355
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5326 - accuracy: 0.9388
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5812 - accuracy: 0.9406
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5922 - accuracy: 0.9307
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.6646 - accuracy: 0.9278
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6953 - accuracy: 0.9351
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.8476 - accuracy: 0.9336
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.7985 - accuracy: 0.9174
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'tanh', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.9073 - accuracy: 0.9147
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1104 - accuracy: 0.9660
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1453 - accuracy: 0.9550
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1451 - accuracy: 0.9545
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1622 - accuracy: 0.9497
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1237 - accuracy: 0.9622
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1505 - accuracy: 0.9531
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1685 - accuracy: 0.9478
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': None, 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 5ms/step - loss: 0.2073 - accuracy: 0.9342
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5195 - accuracy: 0.9400
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 4s 4ms/step - loss: 0.6190 - accuracy: 0.9378
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5792 - accuracy: 0.9302
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.6609 - accuracy: 0.9285
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.7151 - accuracy: 0.9341
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.0, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.8610 - accuracy: 0.9319
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 32, 'epochs': 1}
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.7671 - accuracy: 0.9167
# {'conv': True, 'conv_sizes': [64, 64], 'conv_kernel_size': [5, 5], 'conv_activation': 'relu', 'regularizer': 'l2', 'dense_sizes': [128, 128], 'dense_activation': 'relu', 'output_activation': 'softmax', 'dropout_rate': 0.2, 'optimizer': 'adam', 'loss': 'categorical_crossentropy', 'batch_size': 64, 'epochs': 1}
# 938/938 [==============================] - 5s 5ms/step - loss: 0.9166 - accuracy: 0.9101
